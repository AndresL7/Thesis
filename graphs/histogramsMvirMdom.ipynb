# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Ruta figures por capitulo
results_path = "/home/andres/Dropbox/Manuscrito_Thesis/Tesis_Andrés_López/figures/results/"

# %%
halo3_z0 = pd.read_csv('../../results/Halos_50_3_z0.dat', delim_whitespace=True, header=None, names=['X', 'Y', 'Z','Mvir','Rvir','Mdom','Npart'])
# Out:
# /tmp/ipykernel_64920/1623599559.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   halo3_z0 = pd.read_csv('../../results/Halos_50_3_z0.dat', delim_whitespace=True, header=None, names=['X', 'Y', 'Z','Mvir','Rvir','Mdom','Npart'])

# %%
halo3_z0 = halo3_z0[halo3_z0['Mdom'] > 0]  # Filtrar halos con Mvir > 10^10 M_sun

# %%
#Histograma de Mvir/Mdom
plt.figure(figsize=(8,6))
plt.hist(np.log10(halo3_z0['Mvir']/halo3_z0['Mdom']), bins=50, color='darkred', edgecolor='black',density=1)
plt.xlabel('log($M_{vir}$ / $M_{dom}$)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
#plt.title('Distribución de Mvir / Mdom en halos', fontsize=16)
#mostrar los ticks secundarios entre los ticks principales
plt.minorticks_on()
#mostrar los ticks de arriba y la derecha hacia adentro
plt.tick_params(axis='both', which='both', top=True, right=True, direction='in')
plt.tight_layout()
plt.savefig(results_path + 'Mvir_Mdom_histogram_3.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
halo2_z0 = pd.read_csv('../../results/Halos_50_2_z0.dat', delim_whitespace=True, header=None, names=['X', 'Y', 'Z','Mvir','Rvir','Mdom','Npart'])
# Out:
# /tmp/ipykernel_64920/1396698443.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   halo2_z0 = pd.read_csv('../../results/Halos_50_2_z0.dat', delim_whitespace=True, header=None, names=['X', 'Y', 'Z','Mvir','Rvir','Mdom','Npart'])

# %%
halo2_z0 = halo2_z0[halo2_z0['Mdom'] > 0]  # Filtrar halos con Mvir > 10^10 M_sun

# %%
#Histograma de Mvir/Mdom
plt.figure(figsize=(8,6))
plt.hist(np.log10(halo2_z0['Mvir']/halo2_z0['Mdom']), bins=50, color='darkred', edgecolor='black',density=1)
plt.xlabel('log(M$_\mathrm{vir}$ / M$_\mathrm{dom}$)', fontsize=14)
plt.ylabel('F(log(M$_\mathrm{vir}$ / M$_\mathrm{dom}$))', fontsize=14)
#plt.title('Distribución de Mvir / Mdom en halos', fontsize=16)
#mostrar los ticks secundarios entre los ticks principales
plt.minorticks_on()
#mostrar los ticks de arriba y la derecha hacia adentro
plt.tick_params(axis='both', which='both', top=True, right=True, direction='in')
plt.tight_layout()
plt.savefig(results_path + 'Mvir_Mdom_histogram_2.png', dpi=300, bbox_inches='tight')
plt.show()
